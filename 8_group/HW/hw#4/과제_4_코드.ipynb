# %%
# 파이썬 ≥3.5 필수
import sys
assert sys.version_info >= (3, 5)

# 사이킷런 ≥0.20 필수
import sklearn
assert sklearn.__version__ >= "0.20"

# 코랩에서 실행되는 노트북인가요?
IS_COLAB = "google.colab" in sys.modules

# 텐서플로 ≥2.0 필수
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

if not tf.config.list_physical_devices('GPU'):
    print("감지된 GPU가 없습니다. GPU가 없으면 CNN은 매우 느릴 수 있습니다.")
    if IS_COLAB:
        print("런타임 > 런타임 유형 변경 메뉴를 선택하고 하드웨어 가속기로 GPU를 고르세요.")

# 공통 모듈 임포트
import numpy as np
import os

# 노트북 실행 결과를 동일하게 유지하기 위해
np.random.seed(42)
tf.random.set_seed(42)

# 깔끔한 그래프 출력을 위해
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# 그림을 저장할 위치
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "cnn"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("그림 저장", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train, X_valid = X_train_full[:-5000], X_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]

X_mean = X_train.mean(axis=0, keepdims=True)
X_std = X_train.std(axis=0, keepdims=True) + 1e-7
X_train = (X_train - X_mean) / X_std
X_valid = (X_valid - X_mean) / X_std
X_test = (X_test - X_mean) / X_std

X_train = X_train[..., np.newaxis]
X_valid = X_valid[..., np.newaxis]
X_test = X_test[..., np.newaxis]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 2s 0us/step

# %%
from functools import partial

DefaultConv2D = partial(keras.layers.Conv2D,
                        kernel_size=3, activation='relu', padding="SAME")

model = keras.models.Sequential([
    DefaultConv2D(filters=32, kernel_size=3, padding="same", input_shape=[28, 28, 1]),
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=64, kernel_size=3, activation="relu", padding="same"),
    DefaultConv2D(filters=64, kernel_size=3, activation="relu", padding="same"),
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=128, kernel_size=3, activation="relu", padding="same"),
    DefaultConv2D(filters=128, kernel_size=3, activation="relu", padding="same"),
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Flatten(),
    keras.layers.Dense(units=64, activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(units=10, activation='softmax'),
])

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="nadam", metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid))
score = model.evaluate(X_test, y_test)
X_new = X_test[:10] # 새로운 이미지처럼 사용합니다
y_pred = model.predict(X_new)
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 30s 8ms/step - loss: 0.5299 - accuracy: 0.8137 - val_loss: 0.3214 - val_accuracy: 0.8794
# Epoch 2/100
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.3343 - accuracy: 0.8832 - val_loss: 0.2723 - val_accuracy: 0.8934
# Epoch 3/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.2776 - accuracy: 0.9011 - val_loss: 0.2718 - val_accuracy: 0.8990
# Epoch 4/100
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.2439 - accuracy: 0.9139 - val_loss: 0.2343 - val_accuracy: 0.9104
# Epoch 5/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.2189 - accuracy: 0.9210 - val_loss: 0.2417 - val_accuracy: 0.9096
# Epoch 6/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1995 - accuracy: 0.9280 - val_loss: 0.2610 - val_accuracy: 0.9140
# Epoch 7/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1810 - accuracy: 0.9344 - val_loss: 0.2430 - val_accuracy: 0.9190
# Epoch 8/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1696 - accuracy: 0.9380 - val_loss: 0.2546 - val_accuracy: 0.9198
# Epoch 9/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1543 - accuracy: 0.9430 - val_loss: 0.2607 - val_accuracy: 0.9150
# Epoch 10/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1426 - accuracy: 0.9473 - val_loss: 0.2676 - val_accuracy: 0.9212
# Epoch 11/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1316 - accuracy: 0.9512 - val_loss: 0.3275 - val_accuracy: 0.9162
# Epoch 12/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1264 - accuracy: 0.9528 - val_loss: 0.2972 - val_accuracy: 0.9166
# Epoch 13/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1202 - accuracy: 0.9546 - val_loss: 0.3067 - val_accuracy: 0.9164
# Epoch 14/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1082 - accuracy: 0.9594 - val_loss: 0.3467 - val_accuracy: 0.9132
# Epoch 15/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1062 - accuracy: 0.9603 - val_loss: 0.3367 - val_accuracy: 0.9204
# Epoch 16/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0999 - accuracy: 0.9635 - val_loss: 0.3379 - val_accuracy: 0.9222
# Epoch 17/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1027 - accuracy: 0.9633 - val_loss: 0.3602 - val_accuracy: 0.9122
# Epoch 18/100
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.0995 - accuracy: 0.9642 - val_loss: 0.3417 - val_accuracy: 0.9090
# Epoch 19/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0916 - accuracy: 0.9661 - val_loss: 0.4399 - val_accuracy: 0.9184
# Epoch 20/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0931 - accuracy: 0.9677 - val_loss: 0.3640 - val_accuracy: 0.9186
# Epoch 21/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0865 - accuracy: 0.9689 - val_loss: 0.4521 - val_accuracy: 0.9158
# Epoch 22/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0914 - accuracy: 0.9687 - val_loss: 0.3981 - val_accuracy: 0.9170
# Epoch 23/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0796 - accuracy: 0.9726 - val_loss: 0.4635 - val_accuracy: 0.9148
# Epoch 24/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0842 - accuracy: 0.9699 - val_loss: 0.4376 - val_accuracy: 0.9136
# Epoch 25/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0800 - accuracy: 0.9733 - val_loss: 0.4313 - val_accuracy: 0.9174
# Epoch 26/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0807 - accuracy: 0.9723 - val_loss: 0.4744 - val_accuracy: 0.9138
# Epoch 27/100
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0798 - accuracy: 0.9724 - val_loss: 0.4451 - val_accuracy: 0.9164
# Epoch 28/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0771 - accuracy: 0.9743 - val_loss: 0.5155 - val_accuracy: 0.9158
# Epoch 29/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0766 - accuracy: 0.9740 - val_loss: 0.4293 - val_accuracy: 0.9196
# Epoch 30/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0885 - accuracy: 0.9713 - val_loss: 0.4956 - val_accuracy: 0.9194
# Epoch 31/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0763 - accuracy: 0.9756 - val_loss: 0.5842 - val_accuracy: 0.9102
# Epoch 32/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0717 - accuracy: 0.9755 - val_loss: 0.5386 - val_accuracy: 0.9172
# Epoch 33/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0814 - accuracy: 0.9737 - val_loss: 0.5003 - val_accuracy: 0.9118
# Epoch 34/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0695 - accuracy: 0.9770 - val_loss: 0.5956 - val_accuracy: 0.9118
# Epoch 35/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0778 - accuracy: 0.9749 - val_loss: 0.5513 - val_accuracy: 0.9108
# Epoch 36/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0624 - accuracy: 0.9788 - val_loss: 0.6096 - val_accuracy: 0.9136
# Epoch 37/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0824 - accuracy: 0.9743 - val_loss: 0.5484 - val_accuracy: 0.9118
# Epoch 38/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0676 - accuracy: 0.9780 - val_loss: 0.5741 - val_accuracy: 0.9114
# Epoch 39/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0705 - accuracy: 0.9778 - val_loss: 0.5458 - val_accuracy: 0.9110
# Epoch 40/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0698 - accuracy: 0.9782 - val_loss: 0.5716 - val_accuracy: 0.9154
# Epoch 41/100
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.0767 - accuracy: 0.9776 - val_loss: 0.5790 - val_accuracy: 0.9146
# Epoch 42/100
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.0829 - accuracy: 0.9759 - val_loss: 0.5468 - val_accuracy: 0.9048
# Epoch 43/100
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.0786 - accuracy: 0.9765 - val_loss: 0.5511 - val_accuracy: 0.9132
# Epoch 44/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0604 - accuracy: 0.9809 - val_loss: 0.5771 - val_accuracy: 0.9160
# Epoch 45/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0650 - accuracy: 0.9801 - val_loss: 0.5155 - val_accuracy: 0.9160
# Epoch 46/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0743 - accuracy: 0.9776 - val_loss: 0.5971 - val_accuracy: 0.9114
# Epoch 47/100
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0689 - accuracy: 0.9792 - val_loss: 0.5854 - val_accuracy: 0.9116
# Epoch 48/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0686 - accuracy: 0.9797 - val_loss: 0.6871 - val_accuracy: 0.9134
# Epoch 49/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0668 - accuracy: 0.9801 - val_loss: 0.6588 - val_accuracy: 0.9170
# Epoch 50/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0674 - accuracy: 0.9794 - val_loss: 0.6221 - val_accuracy: 0.9166
# Epoch 51/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0820 - accuracy: 0.9762 - val_loss: 0.5670 - val_accuracy: 0.9156
# Epoch 52/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0649 - accuracy: 0.9805 - val_loss: 0.6331 - val_accuracy: 0.9162
# Epoch 53/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0655 - accuracy: 0.9802 - val_loss: 0.6870 - val_accuracy: 0.9174
# Epoch 54/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0679 - accuracy: 0.9792 - val_loss: 0.7751 - val_accuracy: 0.9180
# Epoch 55/100
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.0732 - accuracy: 0.9783 - val_loss: 0.7242 - val_accuracy: 0.9130
# Epoch 56/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0814 - accuracy: 0.9767 - val_loss: 0.6794 - val_accuracy: 0.9106
# Epoch 57/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0677 - accuracy: 0.9804 - val_loss: 0.7630 - val_accuracy: 0.9096
# Epoch 58/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0780 - accuracy: 0.9775 - val_loss: 0.7027 - val_accuracy: 0.9066
# Epoch 59/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0796 - accuracy: 0.9777 - val_loss: 0.6429 - val_accuracy: 0.9136
# Epoch 60/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0662 - accuracy: 0.9807 - val_loss: 0.7384 - val_accuracy: 0.9094
# Epoch 61/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0725 - accuracy: 0.9795 - val_loss: 0.6641 - val_accuracy: 0.9048
# Epoch 62/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0775 - accuracy: 0.9784 - val_loss: 0.7743 - val_accuracy: 0.9036
# Epoch 63/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0738 - accuracy: 0.9787 - val_loss: 0.8102 - val_accuracy: 0.9164
# Epoch 64/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0721 - accuracy: 0.9800 - val_loss: 0.7817 - val_accuracy: 0.9106
# Epoch 65/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0775 - accuracy: 0.9792 - val_loss: 0.7475 - val_accuracy: 0.9090
# Epoch 66/100
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0753 - accuracy: 0.9792 - val_loss: 0.7587 - val_accuracy: 0.9120
# Epoch 67/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0670 - accuracy: 0.9811 - val_loss: 0.8692 - val_accuracy: 0.9088
# Epoch 68/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0843 - accuracy: 0.9776 - val_loss: 0.7063 - val_accuracy: 0.9112
# Epoch 69/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1113 - accuracy: 0.9729 - val_loss: 0.8051 - val_accuracy: 0.9072
# Epoch 70/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0907 - accuracy: 0.9764 - val_loss: 1.0326 - val_accuracy: 0.9188
# Epoch 71/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0791 - accuracy: 0.9797 - val_loss: 0.9182 - val_accuracy: 0.9064
# Epoch 72/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0641 - accuracy: 0.9822 - val_loss: 0.9641 - val_accuracy: 0.9116
# Epoch 73/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0744 - accuracy: 0.9800 - val_loss: 0.9482 - val_accuracy: 0.9116
# Epoch 74/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0742 - accuracy: 0.9800 - val_loss: 0.8858 - val_accuracy: 0.9108
# Epoch 75/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0747 - accuracy: 0.9801 - val_loss: 0.9921 - val_accuracy: 0.9138
# Epoch 76/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0831 - accuracy: 0.9782 - val_loss: 0.7757 - val_accuracy: 0.9106
# Epoch 77/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0806 - accuracy: 0.9780 - val_loss: 0.8262 - val_accuracy: 0.9056
# Epoch 78/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0898 - accuracy: 0.9770 - val_loss: 0.9343 - val_accuracy: 0.9132
# Epoch 79/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0782 - accuracy: 0.9790 - val_loss: 0.9056 - val_accuracy: 0.9096
# Epoch 80/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0842 - accuracy: 0.9777 - val_loss: 0.9904 - val_accuracy: 0.9122
# Epoch 81/100
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.0834 - accuracy: 0.9787 - val_loss: 0.9224 - val_accuracy: 0.9076
# Epoch 82/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0947 - accuracy: 0.9768 - val_loss: 0.8304 - val_accuracy: 0.9106
# Epoch 83/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1009 - accuracy: 0.9735 - val_loss: 0.9909 - val_accuracy: 0.9068
# Epoch 84/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0730 - accuracy: 0.9808 - val_loss: 0.7926 - val_accuracy: 0.9098
# Epoch 85/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0962 - accuracy: 0.9763 - val_loss: 0.7786 - val_accuracy: 0.9116
# Epoch 86/100
# 1719/1719 [==============================] - 15s 9ms/step - loss: 0.0718 - accuracy: 0.9813 - val_loss: 1.0126 - val_accuracy: 0.9116
# Epoch 87/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0875 - accuracy: 0.9785 - val_loss: 1.0299 - val_accuracy: 0.9136
# Epoch 88/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0855 - accuracy: 0.9789 - val_loss: 1.0552 - val_accuracy: 0.9122
# Epoch 89/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0818 - accuracy: 0.9799 - val_loss: 1.1384 - val_accuracy: 0.9074
# Epoch 90/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0983 - accuracy: 0.9758 - val_loss: 1.1331 - val_accuracy: 0.9146
# Epoch 91/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1341 - accuracy: 0.9711 - val_loss: 0.9560 - val_accuracy: 0.9056
# Epoch 92/100
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.1012 - accuracy: 0.9750 - val_loss: 1.0849 - val_accuracy: 0.9090
# Epoch 93/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0843 - accuracy: 0.9787 - val_loss: 1.2006 - val_accuracy: 0.9106
# Epoch 94/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0908 - accuracy: 0.9769 - val_loss: 1.1239 - val_accuracy: 0.9120
# Epoch 95/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0800 - accuracy: 0.9811 - val_loss: 0.8230 - val_accuracy: 0.9052
# Epoch 96/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0932 - accuracy: 0.9773 - val_loss: 1.1416 - val_accuracy: 0.9110
# Epoch 97/100
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0843 - accuracy: 0.9797 - val_loss: 0.9950 - val_accuracy: 0.9108
# Epoch 98/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0979 - accuracy: 0.9754 - val_loss: 0.9024 - val_accuracy: 0.9142
# Epoch 99/100
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1449 - accuracy: 0.9651 - val_loss: 1.0531 - val_accuracy: 0.9152
# Epoch 100/100
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.0884 - accuracy: 0.9780 - val_loss: 0.9633 - val_accuracy: 0.9088
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9974 - accuracy: 0.9037
# 1/1 [==============================] - 0s 214ms/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 128)         73856
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 64)                73792
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 351626 (1.34 MB)
# Trainable params: 351626 (1.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9974 - accuracy: 0.9037
# [0.9974091649055481, 0.9036999940872192]
